# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroConst/EQE-358-Metodos-Numericos/blob/main/Lab/Gabarito_Lab_01_Solvente_Biodegrad%C3%A1vel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 01 – Ajuste de Capacidade Térmica
#
# ## Objetivos
# - Implementar regressão por mínimos quadrados
# - Resolver um sistema linear em Python
# - Avaliar a qualidade do ajuste com métricas estatísticas
# - Visualizar dados experimentais
#
# ---
#
# ## Contexto
#
# Foi medido experimentalmente o calor específico de um solvente bio-renovável
# em função da temperatura.
#
# Deseja-se ajustar o modelo:
# $$
# Cp(T) = a0 + a_1T + a_2T^2
# \tag{1}
# $$
# utilizando mínimos quadrados.

# %% [markdown]
# ##🔹 Passo 1 – Importar bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 🔹 Passo 2 – Inserir os dados experimentais
#
# Insira abaixo os vetores de temperatura (T) e capacidade térmica (Cp).

# %%
# Responda aqui

T = np.array([150,160,170,180,190,200,210,220,230,240,250,260,270,280,290,300])
Cp = np.array([1.426,1.447,1.469,1.492,1.516,1.541,1.567,1.596,
               1.627,1.661,1.696,1.732,1.770,1.808,1.848,1.888])

# %% [markdown]
# ##🔹 Passo 3 – Construir a matriz do sistema
#
#
# Deseja-se ajustar o modelo:
#
# $$
# \hat{Cp}_i = a_0 + a_1 T_i + a_2 T_i^2
# \tag{2}
# $$
#
# Definimos a função erro (soma dos quadrados):
#
# $$
# S(a_0,a_1,a_2) =
# \sum_{i=1}^{n}
# \left[
# Cp_i - (a_0 + a_1 T_i + a_2 T_i^2)
# \right]^2
# \tag{3}
# $$
#
# O problema consiste em determinar $a_0, a_1, a_2$ que minimizam $S$.
#
#
# Para minimizar $S$, impomos:
#
# $$
# \frac{\partial S}{\partial a_0} = 0,
# \qquad
# \frac{\partial S}{\partial a_1} = 0,
# \qquad
# \frac{\partial S}{\partial a_2} = 0
# \tag{4}
# $$
#
# A derivação conduz ao seguinte sistema linear:
#
# $$
# \begin{cases}
# n a_0 + a_1 \sum T_i + a_2 \sum T_i^2
# =
# \sum Cp_i
# \\[6pt]
# a_0 \sum T_i + a_1 \sum T_i^2 + a_2 \sum T_i^3
# =
# \sum T_i Cp_i
# \\[6pt]
# a_0 \sum T_i^2 + a_1 \sum T_i^3 + a_2 \sum T_i^4
# =
# \sum T_i^2 Cp_i
# \end{cases}
# \tag{5}
# $$

# %% [markdown]
# ### Forma Matricial
#
# Este é um sistema linear 3×3 para os parâmetros $a_0, a_1, a_2$.
# O sistema linear tem a forma:
#
# $$
# \mathbf{A}\mathbf{x} = \mathbf{b}
# \tag{6}
# $$
#
# onde:
#
# $$
# \mathbf{x} =
# \begin{bmatrix}
# a_0 \\
# a_1 \\
# a_2
# \end{bmatrix}
# $$
#
# $$
# \mathbf{A} =
# \begin{bmatrix}
# n & \sum T_i & \sum T_i^2 \\
# \sum T_i & \sum T_i^2 & \sum T_i^3 \\
# \sum T_i^2 & \sum T_i^3 & \sum T_i^4
# \end{bmatrix}
# $$
#
# $$
# \mathbf{b} =
# \begin{bmatrix}
# \sum Cp_i \\
# \sum T_i Cp_i \\
# \sum T_i^2 Cp_i
# \end{bmatrix}
# $$

# %%
# Número de pontos
n = len(T)

# %%
# Construa a matriz A
A = np.array([
    [n, np.sum(T), np.sum(T**2)],
    [np.sum(T), np.sum(T**2), np.sum(T**3)],
    [np.sum(T**2), np.sum(T**3), np.sum(T**4)]
])
A
# Out:
# array([[         16,        3600,      844000],
#        [       3600,      844000,   205200000],
#        [     844000,   205200000, 51463120000]])

# %%
# Construa o vetor b
b = np.array([np.sum(Cp),np.sum(T*Cp),np.sum((T**2)*Cp)])
b
# Out:
# array([2.6084000e+01, 5.9737700e+03, 1.4235839e+06])

# %% [markdown]
# ## 🔹 Passo 4 – Resolver o sistema linear

# %%
coef = np.linalg.solve(A, b)

a0, a1, a2 = coef

print("Coeficientes ajustados:")
print("a0 =", a0)
print("a1 =", a1)
print("a2 =", a2)
# Out:
# Coeficientes ajustados:
# a0 = 1.328027310924012
# a1 = -0.0005505672268874595
# a2 = 8.077731092429696e-06

# %% [markdown]
# ## 🔹 Passo 5 – Construir a curva ajustada
#
# $$
# \hat{Cp}_i = a_0 + a_1 T_i + a_2 T_i^2
# $$
#
# onde:
#
# - $Cp_i$ = valor experimental
# - $\hat{Cp}_i$ = valor previsto pelo modelo
# - $n$ = número de observações

# %%
T_model = np.linspace(min(T), max(T), 100)

Cp_model = a0 + a1*T_model + a2*T_model**2

# %% [markdown]
# ## 🔹 Passo 6 – Plotar resultados

# %%
plt.scatter(T, Cp,  marker='o', label="Dados experimentais")

plt.plot(T_model, Cp_model, 'r',label="Modelo ajustado")

plt.xlabel("Temperatura (K)")
plt.ylabel("Cp (kJ/kg.K)")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 🔹 Passo 7 – Calcular resíduos
#
# $$
# e_i = y_i - \hat{y}_i
# \tag{7}
# $$
#
# Forma vetorial:
#
# $$
# \mathbf{e} = \mathbf{y} - \hat{\mathbf{y}}
# \tag{8}
# $$

# %%
Cp_pred = a0 + a1*T + a2*T**2

residuos = Cp - Cp_pred

# %% [markdown]
# ## 🔹 Passo 8 – Calcular SSR e RMSE
#
# - Soma dos Quadrados dos Resíduos (SSR)
#
# $$
# SSR = \sum_{i=1}^{n} e_i^2
# \tag{9}
# $$
#
# ou explicitamente:
#
# $$
# SSR = \sum_{i=1}^{n} \left( y_i - \hat{y}_i \right)^2
# \tag{10}
# $$

# %%
SSR = np.sum(residuos**2)

print("SSR =", SSR)
# Out:
# SSR = 2.3673109243699202e-05

# %% [markdown]
# - Erro Quadrático Médio (RMSE)
#
# $$
# RMSE = \sqrt{\frac{1}{n} \sum_{i=1}^{n} e_i^2}
# \tag{11}
# $$
#
# ou
#
# $$
# RMSE = \sqrt{\frac{SSR}{n}}
# \tag{12}
# $$

# %%
RMSE = np.sqrt(SSR / len(T))

print("RMSE =", RMSE)
# Out:
# RMSE = 0.001216375487968744

# %% [markdown]
# ## 🔹 Passo 9 – Calcular R²

# %% [markdown]
# - Média dos Valores Observados
#
# $$
# \bar{y} = \frac{1}{n} \sum_{i=1}^{n} y_i
# \tag{13}
# $$

# %%
Cp_media = np.mean(Cp)

print("Cp_medio =", Cp_media)
# Out:
# Cp_medio = 1.63025

# %% [markdown]
# - Soma Total dos Quadrados (SST)
#
# $$
# SST = \sum_{i=1}^{n} \left( y_i - \bar{y} \right)^2
# \tag{14}
# $$

# %%
SST = np.sum((Cp - Cp_media)**2)

print("SST =", SST)
# Out:
# SST = 0.327213

# %% [markdown]
# - Coeficiente de Determinação (R²)
#
# $$
# R^2 = 1 - \frac{SSR}{SST}
# \tag{15}
# $$

# %%
R2 = 1 - SSR/SST

print("R² =", R2)
# Out:
# R² = 0.9999276522960772
